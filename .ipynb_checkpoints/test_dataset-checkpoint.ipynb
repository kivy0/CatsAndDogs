# %%
from pathlib import Path
import numpy as np
import torch
import cv2
import albumentations as A

from dataset.image_utils import *
from dataset.datasets import *
from dataloader import config, train_loader, val_loader, test_loader
# %reload_ext autoreload
# %autoreload 2

# %%
A = iter(val_loader)
Batch = next(A)
Batch
# Out:
# {'image': tensor([[[[0.9647, 0.9686, 0.9686,  ..., 1.0000, 1.0000, 1.0000],
#            [0.9647, 0.9686, 0.9686,  ..., 1.0000, 1.0000, 1.0000],
#            [0.9647, 0.9647, 0.9647,  ..., 1.0000, 1.0000, 1.0000],
#            ...,
#            [0.9529, 0.9569, 0.9569,  ..., 0.9922, 0.9922, 0.9922],
#            [0.9490, 0.9529, 0.9529,  ..., 0.9922, 0.9922, 0.9922],
#            [0.9490, 0.9529, 0.9529,  ..., 0.9922, 0.9922, 0.9922]],
#
#           [[0.9059, 0.9098, 0.9137,  ..., 0.9647, 0.9647, 0.9647],
#            [0.9059, 0.9098, 0.9137,  ..., 0.9647, 0.9647, 0.9647],
#            [0.9059, 0.9059, 0.9098,  ..., 0.9608, 0.9608, 0.9608],
#            ...,
#            [0.9059, 0.9098, 0.9098,  ..., 0.9882, 0.9882, 0.9882],
#            [0.9020, 0.9059, 0.9059,  ..., 0.9882, 0.9882, 0.9882],
#            [0.9020, 0.9020, 0.9059,  ..., 0.9882, 0.9882, 0.9882]],
#
#           [[0.8941, 0.8980, 0.9020,  ..., 0.9294, 0.9294, 0.9294],
# ...

# %%
train_loader.batch_size
# Out:
# 8

# %%
Batch["image"].shape
# Out:
# torch.Size([8, 3, 256, 256])

# %%
Batch["label"]
# Out:
# tensor([1, 1, 1, 0, 0, 1, 1, 1])

# %%
config.dataset
# Out:
# DatasetSettings(train_path=WindowsPath('train'), val_path=WindowsPath('val'), train_preprocessing_config=WindowsPath('conf/train_preprocessing.yaml'), val_preprocessing_config=WindowsPath('conf/val_preprocessing.yaml'), loader_num_workers=2, batch_size=8)

# %%
DATASET_DIR = Path('train')
CONFIG_FILENAME = 'conf/train_preprocessing.yaml'

# %%
dataset = ImageDirsDataset(images_dir=DATASET_DIR, preprocessing_config=CONFIG_FILENAME)
len(dataset)
# Out:
# 15000

# %%
idx = np.random.randint(0, len(dataset))
sample = dataset[idx]

# %%
sample["label"]
# Out:
# 0

# %%
sample["image"].max()
# Out:
# tensor(1.)

# %%
sample["image"].min()
# Out:
# tensor(0.1922)

# %%
sample["image"].shape
# Out:
# torch.Size([3, 224, 224])

# %%
from model import transfer_model
from train import train_model
import torch.optim as optim
from torch.nn import BCELoss

# %%
optimizer = optim.Adam(transfer_model.parameters(), lr=0.01)
train_model(transfer_model, optimizer, BCELoss(), train_loader, val_loader, "cpu", 10)
# Out:
#  Train Epoch: 1/10 [6984/15000 (47%)]	Train Loss: 1.152868
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 optimizer = optim.Adam(transfer_model.parameters(), lr=0.01)
# ----> 2 train_model(transfer_model, optimizer, BCELoss(), train_loader, val_loader, "cpu", 10)
#
# File E:\development\cat\train.py:56, in train_model(model, optimizer, loss_fn, train_loader, val_loader, device, num_epochs)
#      52 y_batch = batch['label'].to(device)
#      54 optimizer.zero_grad()
# ---> 56 y_pred = model(x_batch).squeeze()
#      57 predicted = (y_pred > 0.5).float()
#      58 loss = loss_fn(y_pred.float().to(device), y_batch.float())
#
# File ~\Anaconda3\envs\newVer\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
# ...

# %%
print(torch.cuda.is_available())
# Out:
# False
